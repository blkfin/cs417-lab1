# %% [markdown]
# <a href="https://colab.research.google.com/github/blkfin/cs417-lab1/blob/main/Untitled169.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# console.log('hello world');
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# hello world
