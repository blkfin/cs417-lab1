# %% [markdown]
# <a href="https://colab.research.google.com/github/blkfin/cs417-lab1/blob/main/CS417_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 417 - Lab 1: Google Colab Introduction
# **Date:** 1/19/26
# This notebook demonstrates basic Python concepts including:
# - Print statements
# - Variables
# - Basic arithmetic operations
# - String formatting

# %%
# Basic print statements
print("Welcome to Google Colab!")
print("Python makes programming fun!")
# Out:
# Welcome to Google Colab!
# Python makes programming fun!

# %%
favorite_food = "frogs"      # Replace with your favorite food
favorite_number = 1_000_000       # Replace with your favorite number
favorite_color = "blue"      # Replace with your favorite color

print("My favorite food is:", favorite_food)
print("My favorite number is:", favorite_number)
print("My favorite color is:", favorite_color)
# Out:
# My favorite food is: frogs
# My favorite number is: 1000000
# My favorite color is: blue
